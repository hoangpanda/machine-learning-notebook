# %% [markdown]
# ### Getting started

# %%
import pandas as pd 
import numpy as np

# %%
 df = pd.read_csv('chipotle.tsv', sep='\t')

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
list(df.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043          1
# top             NaN          NaN  Chicken Bowl        [Diet Coke]    float64
# freq            NaN          NaN           726                134       4622
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
df.loc[(df.quantity >= 10) , ['order_id', 'quantity']]
# Out:
#       order_id  quantity
# 3598      1443        15
# 4152      1660        10

# %%
df.iloc[3:11, :-1]
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description
# 3                                                 NaN
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                 NaN
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# ...

# %%
df.iloc[9]
# Out:
# order_id                                                              5
# quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# item_price                                                      float64
# Name: 9, dtype: object

# %%
df.item_price.apply(lambda x: x[1:])
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.item_price.dtype
# Out:
# dtype('O')

# %%
df.item_price = df.item_price.apply(lambda x: float(x[1:]))

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df['total_price'] = df['quantity']*df['item_price']

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %%
print(sum(df.total_price))
print(df.total_price.sum())
# Out:
# 39237.020000000055
# 39237.02

# %%
c = df.groupby('item_name')['quantity', 'item_name'].apply(print)
c.sort_values(ascending=False)
# Out:
#       quantity          item_name
# 298          1  6 Pack Soft Drink
# 341          1  6 Pack Soft Drink
# 357          1  6 Pack Soft Drink
# 388          1  6 Pack Soft Drink
# 417          1  6 Pack Soft Drink
# 553          1  6 Pack Soft Drink
# 639          1  6 Pack Soft Drink
# 721          1  6 Pack Soft Drink
# 743          1  6 Pack Soft Drink
# 879          1  6 Pack Soft Drink
# 1026         1  6 Pack Soft Drink
# 1051         1  6 Pack Soft Drink
# 1124         1  6 Pack Soft Drink
# 1167         1  6 Pack Soft Drink
# 1260         1  6 Pack Soft Drink
# 1279         1  6 Pack Soft Drink
# 1392         1  6 Pack Soft Drink
# 1755         1  6 Pack Soft Drink
# 1758         1  6 Pack Soft Drink
# 1849         1  6 Pack Soft Drink
# 1860         1  6 Pack Soft Drink
# 1916         1  6 Pack Soft Drink
# 1922         1  6 Pack Soft Drink
# 1937         1  6 Pack Soft Drink
# 1976         1  6 Pack Soft Drink
# 2108         1  6 Pack Soft Drink
# ...

# %%
df['item_name'].nunique()
# Out:
# 50

# %%
df['item_name'].count()
# Out:
# 4622
